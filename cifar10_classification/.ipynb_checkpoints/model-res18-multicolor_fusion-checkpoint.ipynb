# %% [markdown]
# # 쉬펄10 resnet18 baseline.
# - pytorch
# - resnet 18
# - early stop ( https://github.com/Bjarten/early-stopping-pytorch )
#
# - 빠른 전처리 방법 https://dacon.io/competitions/official/235874/codeshare/4575?page=1&dtype=recent

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import librosa, librosa.display 
from tqdm import tqdm

from pytorchtools.pytorchtools import EarlyStopping # 현재 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %% [markdown]
# # 데이터 확인

# %%
print("target 들 ")
glob('./data/train/*')
# Out:
# target 들
# ['./data/train\\airplane',
#  './data/train\\automobile',
#  './data/train\\bird',
#  './data/train\\cat',
#  './data/train\\deer',
#  './data/train\\dog',
#  './data/train\\frog',
#  './data/train\\horse',
#  './data/train\\ship',
#  './data/train\\truck']

# %% [markdown]
# ## train set 확인

# %%
print("귀찮네 그냥 파일 다 넣고 액셀로 분류해주지")


## train set

airplane = glob('./data/train/airplane/*.jpg');print('airplane train: ',len(airplane))
automobile = glob('./data/train/automobile/*.jpg');print('automobile train: ',len(automobile))
bird = glob('./data/train/bird/*.jpg');print('bird train: ',len(bird))
cat = glob('./data/train/cat/*.jpg');print('cat train: ',len(cat))
deer = glob('./data/train/deer/*.jpg');print('deer train: ',len(deer))
dog = glob('./data/train/dog/*.jpg');print('dog train: ',len(dog))
frog = glob('./data/train/frog/*.jpg');print('frog train: ',len(frog))
horse = glob('./data/train/horse/*.jpg');print('horse train: ',len(horse))
ship = glob('./data/train/ship/*.jpg');print('ship train: ',len(ship))
truck = glob('./data/train/truck/*.jpg');print('truck train: ',len(truck))


## test set
test_set = glob('./data/test/*.jpg');print('test set : ',len(test_set))
# Out:
# 귀찮네 그냥 파일 다 넣고 액셀로 분류해주지
# airplane train:  5000
# automobile train:  5000
# bird train:  5000
# cat train:  5000
# deer train:  5000
# dog train:  5000
# frog train:  5000
# horse train:  5000
# ship train:  5000
# truck train:  5000
# test set :  10000

# %% [markdown]
# 확인결과 모든 데이터 비율이 같으니 stratified나 kfold는 필요 없어 보인다.

# %% [markdown]
# ### airplane 이미지

# %%
air_images=[]
for i in range(9):
    temp=cv2.imread(airplane[i])
    temp=cv2.cvtColor(temp,cv2.COLOR_BGR2RGB)
    air_images.append(temp)
print('이미지 사이즈 : ',temp.shape)
plt.figure(3)
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(air_images[i])
# Out:
# 이미지 사이즈 :  (32, 32, 3)

# %% [markdown]
# ## train valid 제작

# %%
from sklearn.model_selection import train_test_split # train , test 분리에 사용.
from collections import Counter# 라벨을 세준다.

X = []
Y = [] 

##데이터셋 합치기
X = airplane+automobile+bird+cat+deer+dog+frog+horse+ship+truck


## 라벨 제작
Y[:5000]=["airplane",]*5000
Y[5000:10000]=["automobile",]*5000
Y[10000:15000]=["bird",]*5000
Y[15000:20000]=["cat",]*5000
Y[20000:25000]=["deer",]*5000
Y[25000:30000]=["dog",]*5000
Y[30000:35000]=["frog",]*5000
Y[35000:40000]=["horse",]*5000
Y[40000:45000]=["ship",]*5000
Y[45000:50000]=["truck",]*5000

#train, validation set 분류

X, X_valid, Y, Y_valid = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=123)
print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_valid),Counter(Y_valid))
print("---")
# Out:
# ---
# 훈련 셋 :  40000 Counter({'dog': 4000, 'automobile': 4000, 'cat': 4000, 'bird': 4000, 'airplane': 4000, 'ship': 4000, 'deer': 4000, 'horse': 4000, 'truck': 4000, 'frog': 4000})
# 테스트 셋 :  10000 Counter({'automobile': 1000, 'dog': 1000, 'airplane': 1000, 'frog': 1000, 'horse': 1000, 'truck': 1000, 'bird': 1000, 'cat': 1000, 'deer': 1000, 'ship': 1000})
# ---

# %%
cv2.useOptimized()
# Out:
# True

# %%
#데이터 읽어서 저장하기
#더 빠른 연산을 위해서 미리 메모리에 올려두기
#단, 메모리 용량이 큰 사람만 권함.

#X=[ cv2.cvtColor( cv2.imread(x),cv2.COLOR_BGR2RGB) for x in tqdm(X) ]
#X_valid=[ cv2.cvtColor(cv2.imread(x),cv2.COLOR_BGR2RGB) for x in tqdm(X_valid) ]

# %%
import pickle

## Save pickle
#with open("./data/train.pickle","wb") as fw:
#    pickle.dump(X, fw)
    
#with open("./data/valid.pickle","wb") as fw:
#    pickle.dump(X_valid, fw)

# %%
## Load pickle
with open("./data/train.pickle","rb") as fr:
    X = pickle.load(fr)

with open("./data/valid.pickle","rb") as fr:
    X_valid = pickle.load(fr)

# %%
train_set_img_HSV = [ cv2.cvtColor(x,cv2.COLOR_RGB2HSV) for x in X ]
valid_set_img_HSV = [ cv2.cvtColor(x,cv2.COLOR_RGB2HSV) for x in X_valid ]

# %%
np.array(X).shape
# Out:
# (40000, 32, 32, 3)

# %%
X[0][:,:,0].shape
# Out:
# (32, 32)

# %%
#test_set_img = [ cv2.cvtColor(cv2.imread(x),cv2.COLOR_BGR2RGB) for x in test_set ]

# %%
#with open("./data/test.pickle","wb") as fw:
#    pickle.dump(test_set_img, fw)

# %%
with open("./data/test.pickle","rb") as fr:
    test_set_img = pickle.load(fr)

# %%
test_set_img_HSV = [ cv2.cvtColor(x,cv2.COLOR_RGB2HSV) for x in test_set_img ]

# %% [markdown]
# # 데이터 정의

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]


#train, valid dataset / Y_data와 data_list만 바꿔주면 train, valid 바꿀 수 있다.
class cifar_dataset(Dataset):
    def __init__(self,data_list_rgb , data_list_hsv ,Y_data,classes,transform=None):
        # x 데이터
        self.data_list_rgb = data_list_rgb 
        self.data_list_hsv = data_list_hsv
        
        # y 라벨
        self.Y_data = Y_data 
        self.classes = classes
        
        self.label = cifar_dataset.get_label(self.data_list_rgb, self.Y_data )
        self.transform=transform
        
        
        
        
    @classmethod
    def get_label(cls,data_list,Y_data):
        label_list=[]
        for idx,x in enumerate(data_list):
            label_list.append(Y_data[idx])
        return label_list
    
    def __len__(self):
        return len(self.data_list_rgb)
    
    def __getitem__(self,idx):
        img_rgb=self.data_list_rgb[idx]
        img_hsv=self.data_list_hsv[idx]
        
        ## resnet을 사용할 예정이라 따로 이미지 사이즈 조절은 필요없다.
        img_rgb=self.transform(img_rgb).type(torch.float32) # to tesnsor 시 알아서 0~1 값으로 변경된다.
        img_hsv=self.transform(img_hsv).type(torch.float32)
        
        return img_rgb,img_hsv, self.classes.index(self.label[idx])#원핫 인코딩

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]


#test dataset 
class cifar_test_dataset(Dataset):
    def __init__(self,data_list_rgb , data_list_hsv, path_list,classes,transform=None):
        # x 데이터
        self.data_list_rgb = data_list_rgb 
        self.data_list_hsv = data_list_hsv
        
        self.path_list = path_list #path 데이터
        
        self.classes = classes
        self.transform=transform
    
    def __len__(self):
        return len(self.data_list_rgb)
    
    def __getitem__(self,idx):
        img_rgb=self.data_list_rgb[idx]
        img_hsv=self.data_list_hsv[idx]
        
        ## resnet을 사용할 예정이라 따로 이미지 사이즈 조절은 필요없다.
        img_rgb=self.transform(img_rgb).type(torch.float32) # to tesnsor 시 알아서 0~1 값으로 변경된다.
        img_hsv=self.transform(img_hsv).type(torch.float32)
        
        return img_rgb,img_hsv,self.path_list[idx]

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 이미지데이터
EPOCHS = 50 # 전체 데이터 셋을 40번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인
#transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])

train_loader = torch.utils.data.DataLoader(dataset = 
                                           cifar_dataset(
                                               X,
                                               train_set_img_HSV,
                                               Y,
                                               classes,
                                               transform=transforms.Compose([
                                                   transforms.ToTensor(),
                                                   transforms.RandomResizedCrop(512),
                                                   transforms.RandomHorizontalFlip(),
                                                    ]),#표준화
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,# 순서가 암기되는것을 막기위해.
                                           ) 


validation_loader = torch.utils.data.DataLoader(dataset = 
                                           cifar_dataset(
                                               X_valid,
                                               valid_set_img_HSV,
                                               Y_valid,
                                               classes,
                                               transform=transforms.Compose([
                                                   transforms.ToTensor(),
                                                   transforms.Resize((512,512)),
                                               ]),#표준화
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,# 순서가 암기되는것을 막기위해.
                                           )

# %%
test_loader = torch.utils.data.DataLoader(dataset = 
                                           cifar_test_dataset(
                                               test_set_img,
                                               test_set_img_HSV,
                                               test_set,
                                               classes,
                                               transform=transforms.Compose([
                                                   transforms.ToTensor(),
                                                   transforms.Resize((512,512)),
                                                                             ]),
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = False,# 테스트 순서 유지.
                                           )

# %%
# train set mean std rgb 구하기,
#mean_datas=[np.mean(x.numpy(), axis=(2,3)) for x,_ in train_loader] #배치별  rgb 평균
#std_datas=[np.std(x.numpy(), axis=(2,3)) for x,_ in train_loader]

#meanRGB=np.mean(np.array(mean_datas),axis=(0))#각 이미지별 rgb 평균
#stdRGB=np.std(np.array(std_datas),axis=(0))#각 이미지별 rgb 평균

#print("mean r g b : ",np.mean(meanRGB[0]),np.mean(meanRGB[1]),np.mean(meanRGB[2]))
#print("std r g b : ",np.mean(stdRGB[0]),np.mean(stdRGB[1]),np.mean(stdRGB[2]))

#transforms.Normalize(mean=(0.4749191,0.47783136,0.4736403),
#std=(0.059970643,0.061174367,0.062324625)),

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,X_train_hsv,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X_train[0].permute(1,2,0).numpy())
plt.subplot(122)
plt.imshow(X_train_hsv[0].permute(1,2,0).numpy())



#plt.colorbar(format='%+2.0f dB')\
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 3, 512, 512]) type: torch.FloatTensor
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(5)

# %%
# 4. 데이터 확인하기
for (X_valid,X_valid_hsv,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break
    
print(Y_valid[0])
plt.figure(figsize=(5,5))
plt.imshow(X_valid[0].permute(1,2,0).numpy())
plt.xlabel("Time")
plt.ylabel("Frequency")
#plt.colorbar(format='%+2.0f dB')\
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([32, 3, 512, 512]) type: torch.FloatTensor
# Y_valid :  torch.Size([32]) type: torch.LongTensor
# tensor(4)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # RESNET

# %%
class resnet18_feature(nn.Module):
    def __init__(self, embedding_dimension=512, pretrained=False):
        super().__init__()
        self.model = models.resnet18(pretrained=pretrained)
        
        # embedding
        input_features_fc_layer = self.model.fc.in_features # fc layer 채널 수 얻기
        self.model.fc = nn.Linear(input_features_fc_layer, embedding_dimension, bias=True) # fc layer 수정
        
    def forward(self, images):
        embedding = self.model(images) # embedding 생성
        return embedding

    
class resnet18_fusion(nn.Module):
    """Model modified.
    The architecture of our model is the same as standard DenseNet121
    except the classifier layer which has an additional sigmoid function.
    """

    def __init__(self, n_class=10):
        super(resnet18_fusion, self).__init__()

        model1 = resnet18_feature()
        self.rgb_model = model1
        in_features = self.rgb_model.model.fc.out_features
        
        
        model2 = resnet18_feature()
        self.hsv_model = model2


        self.combine = nn.Sequential(
            nn.Linear(in_features * 2, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256,n_class)
        )



    def forward(self, rgb, hsv):

        rgb_feature = self.rgb_model(rgb)
        hsv_feature = self.hsv_model(hsv)

        combine = torch.cat((rgb_feature,
                             hsv_feature,), 1)
        combine = self.combine(combine)

        return combine

# %%
# 모델 
# pretrained

#데이터가 28*28로 단순하다 생각해서 일단 18로 진행







def model_initialize():
    model = resnet18_fusion(n_class=10).cuda()

    return model

model= model_initialize()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# resnet18_fusion(
#   (rgb_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=512, bias=True)
#     )
#   )
#   (hsv_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=512, bias=True)
#     )
#   )
#   (combine): Sequential(
#     (0): Linear(in_features=1024, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,hsv,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        hsv = hsv.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image,hsv) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image,hsv, label in valid_loader:
            image = image.to(DEVICE)
            hsv = hsv.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image,hsv)
            
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#10. 학습 및 평가.
#early stop

check_path = './checkpoint/checkpoint_resnet18_multicolor_512.pt'
print(check_path)
early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)

best_train_acc=0 # accuracy 기록용
best_valid_acc=0

print("학습 시작\n ----- ")
for Epoch in range(1,EPOCHS+1):
    train_loss,train_accuracy = train(model,train_loader,optimizer,log_interval=31)
    valid_loss,valid_accuracy = evaluate(model, validation_loader)


    print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
          format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))


    early_stopping(valid_loss, model)
    if -early_stopping.best_score == valid_loss:
        best_train_acc, best_valid_acc = train_accuracy,valid_accuracy

    if early_stopping.early_stop:
            print("최고 train acc",best_train_acc)
            print("최고 valid acc",best_valid_acc)
            break

    if Epoch==EPOCHS:
        #만약 early stop 없이 마지막 epoch라서 중지 된 경우.
        print("최고 train acc",best_train_acc)
        print("최고 valid acc",best_valid_acc)
# Out:
# ./checkpoint/checkpoint_resnet18_multicolor_512.pt
# 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0558	 Train Acc:34.16 %  | 	Valid Loss:0.0539 	Valid Acc: 38.70 %
#
# Validation loss decreased (inf --> 0.053928).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0461	 Train Acc:46.30 %  | 	Valid Loss:0.0436 	Valid Acc: 51.36 %
#
# Validation loss decreased (0.053928 --> 0.043603).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0415	 Train Acc:52.43 %  | 	Valid Loss:0.0336 	Valid Acc: 62.12 %
#
# Validation loss decreased (0.043603 --> 0.033601).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0386	 Train Acc:56.00 %  | 	Valid Loss:0.0327 	Valid Acc: 63.31 %
#
# Validation loss decreased (0.033601 --> 0.032678).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0367	 Train Acc:58.17 %  | 	Valid Loss:0.0330 	Valid Acc: 62.46 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0350	 Train Acc:60.35 %  | 	Valid Loss:0.0325 	Valid Acc: 62.78 %
#
# Validation loss decreased (0.032678 --> 0.032477).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0335	 Train Acc:61.98 %  | 	Valid Loss:0.0271 	Valid Acc: 70.13 %
#
# Validation loss decreased (0.032477 --> 0.027059).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0323	 Train Acc:63.66 %  | 	Valid Loss:0.0281 	Valid Acc: 69.70 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0313	 Train Acc:64.86 %  | 	Valid Loss:0.0312 	Valid Acc: 65.88 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0303	 Train Acc:65.80 %  | 	Valid Loss:0.0234 	Valid Acc: 74.25 %
#
# Validation loss decreased (0.027059 --> 0.023381).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0294	 Train Acc:66.86 %  | 	Valid Loss:0.0240 	Valid Acc: 73.05 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0286	 Train Acc:67.84 %  | 	Valid Loss:0.0215 	Valid Acc: 76.21 %
#
# Validation loss decreased (0.023381 --> 0.021537).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0279	 Train Acc:68.64 %  | 	Valid Loss:0.0226 	Valid Acc: 75.10 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0273	 Train Acc:69.49 %  | 	Valid Loss:0.0231 	Valid Acc: 74.41 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:15]	 Train Loss:0.0267	 Train Acc:70.06 %  | 	Valid Loss:0.0196 	Valid Acc: 77.96 %
#
# Validation loss decreased (0.021537 --> 0.019627).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0262	 Train Acc:70.49 %  | 	Valid Loss:0.0205 	Valid Acc: 77.69 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0256	 Train Acc:71.41 %  | 	Valid Loss:0.0202 	Valid Acc: 77.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0252	 Train Acc:71.71 %  | 	Valid Loss:0.0190 	Valid Acc: 79.14 %
#
# Validation loss decreased (0.019627 --> 0.018988).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0248	 Train Acc:72.18 %  | 	Valid Loss:0.0197 	Valid Acc: 78.39 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0243	 Train Acc:72.61 %  | 	Valid Loss:0.0191 	Valid Acc: 79.15 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0239	 Train Acc:73.22 %  | 	Valid Loss:0.0198 	Valid Acc: 77.69 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0234	 Train Acc:73.74 %  | 	Valid Loss:0.0190 	Valid Acc: 79.65 %
#
# Validation loss decreased (0.018988 --> 0.018961).  Saving model ...
#
# [EPOCH:23]	 Train Loss:0.0230	 Train Acc:74.29 %  | 	Valid Loss:0.0196 	Valid Acc: 78.85 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:24]	 Train Loss:0.0228	 Train Acc:74.41 %  | 	Valid Loss:0.0202 	Valid Acc: 78.28 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:25]	 Train Loss:0.0220	 Train Acc:75.33 %  | 	Valid Loss:0.0176 	Valid Acc: 80.83 %
#
# Validation loss decreased (0.018961 --> 0.017629).  Saving model ...
#
# [EPOCH:26]	 Train Loss:0.0218	 Train Acc:75.51 %  | 	Valid Loss:0.0186 	Valid Acc: 79.88 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:27]	 Train Loss:0.0214	 Train Acc:76.03 %  | 	Valid Loss:0.0167 	Valid Acc: 81.97 %
#
# Validation loss decreased (0.017629 --> 0.016685).  Saving model ...
#
# [EPOCH:28]	 Train Loss:0.0213	 Train Acc:76.26 %  | 	Valid Loss:0.0186 	Valid Acc: 80.26 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:29]	 Train Loss:0.0211	 Train Acc:76.42 %  | 	Valid Loss:0.0184 	Valid Acc: 80.48 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:30]	 Train Loss:0.0207	 Train Acc:76.90 %  | 	Valid Loss:0.0170 	Valid Acc: 81.54 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:31]	 Train Loss:0.0205	 Train Acc:77.26 %  | 	Valid Loss:0.0176 	Valid Acc: 80.84 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:32]	 Train Loss:0.0201	 Train Acc:77.38 %  | 	Valid Loss:0.0165 	Valid Acc: 82.05 %
#
# Validation loss decreased (0.016685 --> 0.016489).  Saving model ...
#
# [EPOCH:33]	 Train Loss:0.0198	 Train Acc:77.67 %  | 	Valid Loss:0.0170 	Valid Acc: 82.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:34]	 Train Loss:0.0194	 Train Acc:77.95 %  | 	Valid Loss:0.0182 	Valid Acc: 81.33 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:35]	 Train Loss:0.0191	 Train Acc:78.64 %  | 	Valid Loss:0.0163 	Valid Acc: 82.76 %
#
# Validation loss decreased (0.016489 --> 0.016264).  Saving model ...
#
# [EPOCH:36]	 Train Loss:0.0192	 Train Acc:78.57 %  | 	Valid Loss:0.0176 	Valid Acc: 81.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:37]	 Train Loss:0.0189	 Train Acc:78.79 %  | 	Valid Loss:0.0157 	Valid Acc: 83.29 %
#
# Validation loss decreased (0.016264 --> 0.015720).  Saving model ...
#
# [EPOCH:38]	 Train Loss:0.0186	 Train Acc:79.34 %  | 	Valid Loss:0.0165 	Valid Acc: 82.66 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:39]	 Train Loss:0.0181	 Train Acc:79.75 %  | 	Valid Loss:0.0188 	Valid Acc: 80.51 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:40]	 Train Loss:0.0181	 Train Acc:79.60 %  | 	Valid Loss:0.0153 	Valid Acc: 83.73 %
#
# Validation loss decreased (0.015720 --> 0.015335).  Saving model ...
#
# [EPOCH:41]	 Train Loss:0.0178	 Train Acc:79.94 %  | 	Valid Loss:0.0159 	Valid Acc: 83.21 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:42]	 Train Loss:0.0177	 Train Acc:80.04 %  | 	Valid Loss:0.0159 	Valid Acc: 82.99 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:43]	 Train Loss:0.0173	 Train Acc:80.53 %  | 	Valid Loss:0.0152 	Valid Acc: 84.36 %
#
# Validation loss decreased (0.015335 --> 0.015183).  Saving model ...
#
# [EPOCH:44]	 Train Loss:0.0172	 Train Acc:80.63 %  | 	Valid Loss:0.0156 	Valid Acc: 83.65 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:45]	 Train Loss:0.0169	 Train Acc:80.89 %  | 	Valid Loss:0.0161 	Valid Acc: 83.03 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:46]	 Train Loss:0.0168	 Train Acc:81.07 %  | 	Valid Loss:0.0152 	Valid Acc: 84.04 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:47]	 Train Loss:0.0165	 Train Acc:81.48 %  | 	Valid Loss:0.0162 	Valid Acc: 83.01 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:48]	 Train Loss:0.0165	 Train Acc:81.65 %  | 	Valid Loss:0.0145 	Valid Acc: 84.22 %
#
# Validation loss decreased (0.015183 --> 0.014539).  Saving model ...
#
# [EPOCH:49]	 Train Loss:0.0162	 Train Acc:81.91 %  | 	Valid Loss:0.0155 	Valid Acc: 84.13 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:50]	 Train Loss:0.0161	 Train Acc:82.08 %  | 	Valid Loss:0.0152 	Valid Acc: 84.91 %
#
# EarlyStopping counter: 2 out of 5
# 최고 train acc 81.6525
# 최고 valid acc 84.22

# %% [markdown]
# # Test

# %%
check_path = './checkpoint/checkpoint_resnet18_multicolor_512.pt'
model.load_state_dict(torch.load(check_path))

prediction_list = []
file_list = []

with torch.no_grad():
    for image,hsv,path in test_loader:
        image = image.to(DEVICE)
        hsv = hsv.to(DEVICE)
        output = model(image,hsv)
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        
        prediction_list+=prediction.cpu().numpy().tolist()
        file_list+=path
        #print(prediction)

# %%
prediction_list=[ classes[data[0]] for data in prediction_list ]# class 명으로 바꿔주기. 0번 인덱스인 이유는 넘파이가 [5] 이런 형태로 출력되서


print(prediction_list[:10])

# %%
file_list=[name.split("\\")[-1] for name in file_list] #file list 이름 전처리


print(file_list[:10])

# %%
DF=pd.DataFrame({'id':file_list,'target':prediction_list})
DF

# %%
DF.to_csv("./res18_fusion_result.csv",index=False)
